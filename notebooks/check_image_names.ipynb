# %%
import os
import random

# %%
output_dir = "/workspace/datasetvol/mvhuman_data/inconsistent_images"
source_dir = "/workspace/datasetvol/mvhuman_data/mv_captures"

# %%
object_lists = os.listdir(output_dir)

# %%
empty_object_list = [item for item in object_lists if os.listdir(os.path.join(output_dir, item)) == []]

# %% [markdown]
# ## Check image name

# %%
sample_object = empty_object_list[6]

# %%
camera_ids = os.listdir(os.path.join(source_dir, sample_object, 'images_lr'))
image_name = os.listdir(os.path.join(source_dir, sample_object, 'images_lr', camera_ids[2]))

# %%
sorted(image_name)
# Out:
# ['0005_img.jpg',
#  '0105_img.jpg',
#  '0205_img.jpg',
#  '0305_img.jpg',
#  '0405_img.jpg',
#  '0505_img.jpg',
#  '0605_img.jpg',
#  '0705_img.jpg',
#  '0805_img.jpg',
#  '0905_img.jpg',
#  '1005_img.jpg',
#  '1105_img.jpg',
#  '1205_img.jpg',
#  '1305_img.jpg',
#  '1405_img.jpg',
#  '1505_img.jpg',
#  '1605_img.jpg',
#  '1705_img.jpg',
#  '1805_img.jpg',
#  '1905_img.jpg',
#  '2005_img.jpg',
#  '2105_img.jpg']

# %% [markdown]
# ## Normal file name

# %%
sample_nor_object = random.sample([item for item in object_lists if item not in empty_object_list], k=1)[0]

# %%
sample_nor_object
# Out:
# '101276'

# %%
camera_ids = os.listdir(os.path.join(source_dir, sample_nor_object, 'images_lr'))
image_name = os.listdir(os.path.join(source_dir, sample_nor_object, 'images_lr', camera_ids[2]))

# %%
sorted(image_name)
# Out:
# ['0005_img.jpg',
#  '0010_img.jpg',
#  '0015_img.jpg',
#  '0020_img.jpg',
#  '0025_img.jpg',
#  '0030_img.jpg',
#  '0035_img.jpg',
#  '0040_img.jpg',
#  '0045_img.jpg',
#  '0050_img.jpg',
#  '0055_img.jpg',
#  '0060_img.jpg',
#  '0065_img.jpg',
#  '0070_img.jpg',
#  '0075_img.jpg',
#  '0080_img.jpg',
#  '0085_img.jpg',
#  '0090_img.jpg',
#  '0095_img.jpg',
#  '0100_img.jpg',
#  '0105_img.jpg',
#  '0110_img.jpg',
#  '0115_img.jpg',
#  '0120_img.jpg',
#  '0125_img.jpg',
#  '0130_img.jpg',
#  '0135_img.jpg',
#  '0140_img.jpg',
#  '0145_img.jpg',
#  '0150_img.jpg',
#  '0155_img.jpg',
#  '0160_img.jpg',
#  '0165_img.jpg',
#  '0170_img.jpg',
#  '0175_img.jpg',
#  '0180_img.jpg',
#  '0185_img.jpg',
#  '0190_img.jpg',
#  '0195_img.jpg',
#  '0200_img.jpg',
#  '0205_img.jpg',
#  '0210_img.jpg',
#  '0215_img.jpg',
#  '0220_img.jpg',
#  '0225_img.jpg',
#  '0230_img.jpg',
#  '0235_img.jpg',
#  '0240_img.jpg',
#  '0245_img.jpg',
#  '0250_img.jpg',
#  '0255_img.jpg',
#  '0260_img.jpg',
# ...

# %% [markdown]
# ## Conclusion
#
# Object with empty pose synthesis images: timestep is 100 due to pruning
#
# Other object: timestep is 5
